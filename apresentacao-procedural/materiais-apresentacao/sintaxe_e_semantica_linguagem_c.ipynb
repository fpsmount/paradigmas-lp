# %% [markdown]
# # Grupo Verde - Paradigma Procedural
#
# ## Integrantes do grupo
# * Bruno de Alencar Ferreira || 30632391
# * Bruno Henrique Silva Nazaré || 29378443
# * Benjamin da Nóbrega Bezerra  || 29274028
# * Gabriel Oliveira Faria || 29615267
# * Lívia Karla Tavares da Silva || 29682304
# * Pedro Felipe do Carmo Baptista || 30074924

# %% [markdown]
# # 1. **Introdução**

# %% [markdown]
# A linguagem C, uma das mais antigas e influentes linguagens de programação, é fundamental para entender conceitos-chave em computação, como sintaxe e semântica. A sintaxe de C refere-se ao conjunto de regras que define a estrutura correta do código, determinando como as instruções e declarações devem ser escritas para serem compreendidas pelo compilador. Por outro lado, a semântica está relacionada ao significado dessas instruções, o comportamento e a lógica que o programa deve seguir quando executado. Embora um código possa ser sintaticamente correto (compilar sem erros), ele ainda pode conter erros semânticos que levam a resultados inesperados ou indesejados. Compreender esses dois aspectos é essencial para desenvolver programas eficientes e livres de erros, além de facilitar a manutenção e a legibilidade do código.

# %% [markdown]
# # 2. Sintaxe da linguagem C

# %% [markdown]
# A sintaxe são regras detalhadas para cada construção válida na linguagem C. Estas regras estão relacionadas com os tipos, as declarações, as funções e as expressões. Os tipos definem as propriedades dos dados manipulados em um programa. As declarações expressam as partes do programa, podendo dar significado a um identificador, alocar memória, definir conteúdo inicial, definir funções. As funções especificam as ações que um programa executa quando roda. A determinação e alteração de valores, e a chamada de funções de I/O são definidas nas expressões.
#
# As funções são as entidades operacionais básicas dos programas em C, que por sua vez são a união de uma ou mais funções executando cada qual o seu trabalho. Há funções básicas que estão definidas na biblioteca C. As funções printf() e scanf() por exemplo, permitem respectivamente escrever na tela e ler os dados a partir do teclado. O programador também pode definir novas funções em seus programas, como rotinas para cálculos, impressão, etc.

# %% [markdown]
# ## 2.1. Palavras-chave

# %% [markdown]
# ![C.PNG](data:image/png;base64,...)

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)
#
# ![unnamed (2).png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2. Declarações e Expressões

# %% [markdown]
# ![unnamed (1).png](data:image/png;base64,...)

# %% [markdown]
# ## 2.3 estruturas de controle

# %% [markdown]
# ## IF

# %% [markdown]
# ####sintaxe:
# if (condição)comando; else comando; Se a condição avaliar em verdadeiro (qualquer coisa menos 0), o computador executará o comando ou o bloco, de outro modo, se a cláusula else existir, o computador executará o comando ou o bloco que é seu objetivo.
#
# ```
# // Algoritmo que verifica se o número fornecido pelo usuário é maior que 10:
#
# #include <stdio.h>
#
# int main() {
#     int numero;
#
#     printf("Digite um número: ");
#     scanf("%d", &numero);
#
#     if (numero > 10) {
#         printf("O número é maior que 10.\n");
#     }
#
#     return 0;
# }
#
#
# ```

# %% [markdown]
# ##IF - ELSE - IF

# %% [markdown]
# Uma variável é testada sucessivamente contra uma lista de variáveis inteiras ou de caracteres. Depois de encontrar uma coincidência, o comando ou o bloco de comandos é executado.

# %% [markdown]
# ```
# // Algoritmo que recebe um número de entrada e verifica se o valor é igual o segredo (valor gerado aleatoriamente), se o segredo for menor que o número do usuário, retorna mensagem de erro, caso nenhuma das verificações, imprime mensagem de errado, valor abaixo.
#
# #include <stdlib.h>
# #include <time.h>
#
# int main(){
# int num,segredo;
#
# srand(time(NULL));
# segredo=rand()/100;
# printf("Qual e o numero: ");
# scanf("%d",&num);
#       if (segredo==num){
#   printf("Acertou!");
#   printf("\nO numero e %d\n",segredo);
#   }
#     else if (segredo<num)
#   printf("Errado, muito alto!\n");
#     else
#   printf("Errado, muito baixo!\n");
# }
#
# ```

# %% [markdown]
# ##Loop For

# %% [markdown]
# ####Sintaxe

# %% [markdown]
# for(inicialização;condição;incremento) comando;
# O comando for é de alguma maneira encontrado em todas linguagens procedurais de programação. Em sua forma mais simples, a incialização é um comando de atribuição que o compilador usa para estabelecer a variável de controle do loop. A condição é uma expressão de relação que testa a variável de controle do loop contra algum valor para determinar quando o loop terminará. O incremento define a maneira como a variável de controle do loop será alterada cada vez que o computador repetir o loop.

# %% [markdown]
# ```
# // Exemplo de loop do número 1 ao número 99:
#
# int main() {
#   int x;
#   for(x=1;x<100;x++){
#     printf("%d\n",x);
#   }
# }
#
#
# ```

# %% [markdown]
# ##Switch

# %% [markdown]
# ####Sintaxe

# %% [markdown]
# ```
# // Exemplo de usabilidade da função switch():
#
# switch(variável) {
#   case constante1:
#     seqüência de comandos
#     break;
#
#   case constante2:
#     seqüência de comandos break;
#     break;
#
#   default:
#     seqüência de comandos
# }
# ```

# %% [markdown]
# Uma variável é testada sucessivamente contra uma lista de variáveis inteiras ou de caracteres. Depois de encontrar uma coincidência, o comando ou o bloco de comandos é executado. Se nenhuma coincidência for encontrada o comando default será executado. O default é opcional. A seqüência de comandos é executada até que o comando break seja encontrado.

# %% [markdown]
# ```
#
#
# int main() {
#   char x;
#   printf("1. inclusão\n");
#   printf("2. alteração\n");
#   printf("3. exclusão\n");
#   printf(" Digite sua opção:");
#   x=getchar();
#
#   switch(x) {
#     case '1':
#       printf("escolheu inclusão\n");
#     break;
#     case '2':
#       printf("escolheu alteração\n");
#     break;
#     case '3':
#       printf("escolheu exclusão\n");
#     break;
#     default:
#       printf("opção inválida\n");
#   }
# }
# ```

# %% [markdown]
# ##While

# %% [markdown]
# ####Sintaxe

# %% [markdown]
# while(condição) comando;
# Uma maneira possível de executar um laço é utilizando o comando while. Ele permite que o código fique sendo executado numa mesma parte do programa de acordo com uma determinada condição.
# - o comando pode ser vazio, simples ou bloco
# - ele é executado desde que a condição seja verdadeira
# - testa a condição antes de executar o laço

# %% [markdown]
# ```
# // Exemplo de while, enquanto a variavel 'ch' for diferente de "a", o loop continua a solicitar um caractere.
#
# int main() {
#   char ch;
#   while(ch!='a') ch=getchar();
# }
#
# ```

# %% [markdown]
# ##Do While

# %% [markdown]
# ####Sintaxe

# %% [markdown]
# ```
# // Exemplo de do...while(), printando uma tabela de escolha ao usuário e de acordo com a escolha do próprio, os casos imprimem suas respectivas escolhas.
#
# do {
#   comando;
# }
# while(condição);
#
# // Também executa comandos repetitivos. Ex:
#
# int main() {
#   char ch;
#   printf("1. inclusão\n");
#   printf("2. alteração\n");
#   printf("3. exclusão\n");
#   printf(" Digite sua opção:");
#   do {
#       ch=getchar();
#       switch(ch) {
#           case '1':
#             printf("escolheu inclusao\n");
#             break;
#           case '2':
#             printf("escolheu alteracao\n");
#             break;
#           case '3':
#             printf("escolheu exclusao\n");
#             break;
#           case '4':
#             printf("sair\n");
#         }
#       }
#   while(ch!='1' && ch!='2' && ch!='3' && ch!='4');
# }
# ```

# %% [markdown]
# # 3. Semântica da linguagem C

# %% [markdown]
# A semântica é complementar à sintaxe de programas de computador, que se preocupa em descrever as estruturas de uma linguagem de programação
#
# É escrever o código com a estrutura  correta para a execução sequencial do código da linguagem e obtendo o resultado final
#
#
# * Incrementar um contador até 10
#
# ```
# //Exemplo de um incrementador:
#
# //EXEMPLO CORRETO
# int incrementar = 0;
# for (int cont = 0; cont < 10; cont ++){
#       incrementar++;
# }
# //EXEMPLO INCORRETO
# int incrementar = 0;
# for (int cont = 0; cont < 10; cont ++){
# }
# incrementra++;
# ```

# %% [markdown]
# ## 3.1. Definição da Semântica

# %% [markdown]
# A semântica das variáveis em C refere-se ao significado e comportamento das variáveis no contexto do programa. Isso envolve como os valores são atribuídos, como são armazenados na memória e como são utilizados durante a execução do programa. Um exemplo claro pode ilustrar esses conceitos.
#
#
# Exemplo
#
# ```
# #include <stdio.h>
#
# //EXEMPLO CORRETO
#
# int main() {
#     int a = 5;
#     int b = 3;
#     int resultado = a + b;  // Operação válida entre variáveis de mesmo tipo
#     printf("Resultado: %d\n", resultado);  // Saída: Resultado: 8
#     return 0;
# }
#
# // EXEMPLO INCORRETO
#
# #include <stdio.h>
#
# int main() {
#     int a = 5;
#     float b = 3.5;
#     int resultado = a + b;  // Operação incorreta, possível perda de dados
#     printf("Resultado: %d\n", resultado);  // Saída: Resultado é truncado
#     return 0;
# }
# ```

# %% [markdown]
# ## 3.2. Tipos de Dados e Operações

# %% [markdown]
# ```
# #include <stdio.h>
#
# // Função para calcular a área de um retângulo
# int areaRetangulo(int largura, int altura) {
#     return largura * altura;
# }
#
# // Função para calcular a área de um círculo
# float areaCirculo(float raio) {
#     return 3.14 * raio * raio;
# }
#
# int main() {
#     int largura = 5;
#     int altura = 10;
#     float raio = 3.5;
#
#     // Chamadas de funções
#     int areaR = areaRetangulo(largura, altura);
#     float areaC = areaCirculo(raio);
#
#     // Saída dos resultados
#     printf("Área do retângulo: %d\n", areaR);
#     printf("Área do círculo: %.2f\n", areaC);
#
#     return 0;
# }
# ```
#
#  O problema maior de cálculo de áreas é decomposto em subproblemas menores (cálculo de área de retângulo e círculo). Cada subproblema é resolvido por uma função distinta, que pode ser reutilizada e testada separadamente.

# %% [markdown]
# ## 3.3. Semântica de Funções

# %% [markdown]
# As funções são blocos de código reutilizáveis que realizam tarefas específicas. A semântica de funções envolve entender como os parâmetros são passados, como os valores são retornados e o papel dos ponteiros no gerenciamento de memória. Isso é fundamental para o paradigma procedural, no qual a lógica do programa é dividida em procedimentos (funções) que operam sobre dados.
#
# **Passagem por Valor**: Quando um argumento é passado por valor, uma cópia do valor da variável é fornecida à função. Assim, qualquer modificação feita na função não afeta a variável original. Por exemplo:
#
# ```
# void incrementa(int x) {
#     x = x + 1;  // Modifica a cópia de 'x', não o original
# }
# ```
#
# **Passagem por Referência**: Quando se utiliza um ponteiro como parâmetro, a função recebe o endereço da variável, permitindo modificar seu valor diretamente na memória. Isso é chamado de passagem por referência. Exemplo:
#
# ```
# void incrementaPorReferencia(int *x) {
#     *x = *x + 1;  // Modifica o valor original usando o ponteiro
# }
# ```
#
# **Retorno de Funções**: Funções em C podem retornar um valor usando a instrução return. O tipo de dado retornado é especificado na assinatura da função. Funções podem retornar tipos simples como int, float ou até mesmo ponteiros, permitindo a manipulação direta de memória.
#
# ```
# int soma(int a, int b) {
#     return a + b;  // Retorna o resultado da soma
# }
# ```
#
#
# **Uso de Ponteiros**: Ponteiros são variáveis que armazenam o endereço de memória de outra variável. Eles são fundamentais para a passagem por referência e para alocação dinâmica de memória. Usando ponteiros, podemos criar funções que manipulam arrays, strings e estruturas complexas, aproveitando o controle manual sobre a memória.
#
# ```
# void troca(int *a, int *b) {
#     int temp = *a;
#     *a = *b;
#     *b = temp;  // Troca os valores de 'a' e 'b' diretamente
# }
# ```
#
# Relação com o Paradigma Procedural:
# No paradigma procedural, funções são usadas para modularizar o código, facilitando a manutenção e a reutilização. A capacidade de passar parâmetros por valor e referência e o uso de ponteiros permite um controle preciso sobre os dados e a execução do programa, maximizando a eficiência e flexibilidade, características fundamentais desse paradigma.

# %% [markdown]
# ## 3.4. Erros Semânticos

# %% [markdown]
# Erros semânticos em C ocorrem quando o código está sintaticamente correto, mas as operações que ele realiza não fazem sentido lógico, resultando em comportamento indesejado ou imprevisível.
#
# Traremos um dos exemplos de um erro semântico.
#
# Acessar uma Variável Não Inicializada
# Quando uma variável é declarada, mas não inicializada, ela contém um valor "lixo" (valor arbitrário que estava na memória). Utilizar essa variável antes de atribuir um valor válido pode levar a resultados inesperados.
#
# ```
# #include <stdio.h>
#
# int main() {
#     int x;  // Variável 'x' declarada, mas não inicializada
#     printf("%d\n", x);  // Erro semântico: 'x' contém um valor indefinido
#     return 0;
# }
# ```
#
# No exemplo acima, a variável x não foi definida, então seu valor é indefinido e a saída pode variar.

# %% [markdown]
# # 4. Diferenças entre Sintaxe e Semântica

# %% [markdown]
# * **Sintaxe** refere-se às regras e estrutura do código-fonte. Erros de sintaxe ocorrem quando o código não segue as regras de escrita da linguagem, como omitir um ponto e vírgula ou usar palavras-chave incorretamente. Erros sintáticos são detectados pelo compilador ou interpretador antes da execução do programa.
#
# * **Semântica** refere-se ao significado do código. Mesmo que um programa esteja sintaticamente correto, ele pode conter erros semânticos se o comportamento não fizer sentido lógico. Por exemplo, calcular a raiz quadrada de um número negativo sem tratamento de erro. Erros semânticos são mais difíceis de detectar porque o código é compilado, mas não funciona como esperado.
#
# * ![Captura de tela de 2024-09-07 23-36-50.png](data:image/png;base64,...)

# %% [markdown]
# ## 4.1 Exemplo de Código com Erros Sintáticos e Semânticos

# %% [markdown]
# ```
# // Exemplo de definição de uma lista e tentativa de acesso de uma posição inexistente:
#
# #include <stdio.h>
#
# int main() {
#     int array[3] = {1, 2, 3};
#     printf("Valor: %d\n", array[3]);  // Sintaticamente correto, mas semanticamente incorreto
#     return 0
# }
# ```
#
# * Erro Sintático: O ponto e vírgula ; está faltando após return 0.
# * Erro Semântico: O código tenta acessar array[3], que está fora dos limites do array de tamanho 3 (os índices válidos são 0, 1, e 2).

# %% [markdown]
# # 5. Ferramentas de Análise de Sintaxe e Semântica

# %% [markdown]
# ## 5.1 Compiladores

# %% [markdown]
# Um compilador é um programa de sistema que traduz um programa descrito em uma linguagem de alto nível para um programa equivalente em código de máquina para um processador. Em geral, um compilador não produz diretamente o código de máquina, mas sim um programa em linguagem simbólica (assembly) semanticamente equivalente ao programa em linguagem de alto nível. O programa em linguagem simbólica é então traduzido para o programa em linguagem de máquina através de montadores.
#
# Para desempenhar suas tarefas, um compilador deve executar dois tipos de atividade. A primeira atividade é a análise do código fonte, onde a estrutura e significado do programa de alto nível são reconhecidos. A segunda atividade é a síntese do programa equivalente em linguagem simbólica. Embora conceitualmente seja possível executar toda a análise e apenas então iniciar a síntese, em geral estas duas atividades ocorrem praticamente em paralelo.
#
# Na **análise léxica**, o compilador verifica se o código contém apenas símbolos válidos na linguagem de programação.
#
# Na **análise sintática**, o compilador verifica se as instruções do código seguem a gramática da linguagem. Se a sintaxe estiver incorreta, o compilador emite mensagens de erro que indicam o tipo e a localização do problema.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6. Exemplos Práticos

# %% [markdown]
# ## 6.1 Exemplo de Código Correto

# %% [markdown]
# **Exemplo de código Sintáticamente e Semanticamente corretos:**
#
# ```
# // Função que calcula o fatorial de um número
# #include <stdio.h>
#
# int fatorial(int n) {
#     if (n < 0) {
#         return -1;  // Retorna -1 para indicar um erro (fatorial de número negativo não é definido)
#     }
#     int resultado = 1;
#     for (int i = 1; i <= n; i++) {
#         resultado *= i;  // Multiplica resultado por 'i'
#     }
#     return resultado;
# }
# ```
# ```
# int main() {
#     int numero;
#     printf("Digite um número inteiro não negativo: ");
#     scanf("%d", &numero);
#
#     int resultado = fatorial(numero);
#     if (resultado == -1) {
#         printf("Erro: Fatorial de número negativo não é definido.\n");
#     } else {
#         printf("O fatorial de %d é %d.\n", numero, resultado);
#     }
#
#     return 0;
# }
# ```

# %% [markdown]
# ## 6.2 Exemplo de Código Errado

# %% [markdown]
# * Exemplo de Código com Erros Sintáticos
#
# ```
# #include <stdio.h>
#
# int main() {
#     int x = 5  // Erro: ponto e vírgula ausente
#     printf("O valor de x é: %d\n", x);
#     return 0;
# }
# ```
#
# * Exemplo de Código com Erros Semânticos
#
# ```
# #include <stdio.h>
#
# int main() {
#     int a = 10, b = 0;
#     int resultado = a / b;  // Erro semântico: divisão por zero
#     printf("Resultado: %d\n", resultado);
#     return 0;
# }
# ```

# %% [markdown]
# # 7. Conclusão

# %% [markdown]
# Entender e aplicar corretamente os conceitos de sintaxe e semântica são muitos importantes para qualquer programador, especialmente ao trabalhar com a linguagem C, que é conhecida por sua eficiência, mas também por ser propensa a erros que podem resultar em comportamentos inesperados.
# Diariamente, nós programadores trabalhamos em ambientes em que a utilização correta da sintaxe e da semântica são cruciais para bons resultados no trabalho, portanto, reforçar esses conceitos nunca é demais.
#
# A compreensão clara da sintaxe e da semântica de uma linguagem de programação pode significativamente melhorar a qualidade do código, tornando o mesmo mais legível, manutenível e menos propenso a erros. Um código bem escrito, que possui regras sintáticas e semânticas da linguagem, é mais fácil de depurar, testar e entender por outros desenvolvedores, o que facilita a colaboração e a evolução do software.

# %% [markdown]
# # 8. Referências/Bibliografia

# %% [markdown]
# https://www.inf.ufrgs.br/~binsely/tutorialc.pdf - INTRODUÇÃO À LINGUAGEM C - UNICAMP
#
# https://www.dca.fee.unicamp.br/cursos/EA876/apostila/HTML/node37.html - Compiladores - UNICAMP
#
# http://www.univasf.edu.br/~criston.souza/algoritmos/arquivos/aula02.3.pdf - Linguagens de Programação: sintaxe e semântica de linguagens de programação e conceitos de linguagens interpretadas e compiladas - UNIVASF
#
# https://www.ime.usp.br/~slago/slago-C.pdf - Linguagem C - IME-USP
#
# https://www.inf.ufpr.br/lesoliveira/download/c-completo-total.pdf - C COMPLETO E TOTAL - UFPR
